# %%
# import tensorflow
import tensorflow as tf

# %%
# load train and test sets
df_train, df_test = tf.keras.datasets.mnist.load_data()

# size of train and test sets
len(df_train[0]), len(df_test[0])
# Out:
# (60000, 10000)

# %%
# split dataset into X and y variables
X_train, y_train = df_train[0], df_train[1]
X_test, y_test = df_test[0], df_test[1]

# shape of X
print('Number of datapoints: ' + str(X_train.shape[0]) + '\nNumber of pixels in each image: ' + str(X_train.shape[1]))

# shape of y
print('\nNumber of datapoints: ' + str(y_train.shape))
# Out:
# Number of datapoints: 60000
# Number of pixels in each image: 28
#
# Number of datapoints: (60000,)

# %%
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)
